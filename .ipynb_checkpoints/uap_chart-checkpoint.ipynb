# %%
import pandas as pd
df = pd.read_csv("coords_counts_earth.csv")

# %%
df = df.drop(columns=["Lat", "Lon"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df = df.drop(columns=["Lat", "Lon"])
#
# File ~\.venvs\lede\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File ~\.venvs\lede\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
#    4643             if labels is not None:
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.to_clipboard(index=False)

# %%
df
# Out:
#                             location  duplicate_count
# 0                   HARARE, ZIMBABWE                1
# 1   COLORADO SPRINGS, COLORADO, U.S.                2
# 2         NORTHEASTERN UNITED STATES                2
# 3                            GERMANY                2
# 4                        NETHERLANDS                1
# 5                         AZERBAIJAN                1
# 6                        DETROIT, MI                1
# 7                   BAKU, AZERBAIJAN                1
# 8                  BUDAPEST, HUNGARY                2
# 9                             RUSSIA                3
# 10                     LADAKH, NEPAL                1
# 11                           HUNGARY                1
# 12                         AUSTRALIA                1
# 13                        NEW MEXICO                1
# 14                 MEDITERRANEAN SEA                4
# 15                     PACIFIC OCEAN                1
# ...

# %%
df.sum()
# Out:
# location           HARARE, ZIMBABWECOLORADO SPRINGS, COLORADO, U....
# duplicate_count                                                   74
# dtype: object
